# %% [markdown]
# ### Data Ingestion

# %%
### document structure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is a sample document.",
    metadata={"source": "sample_source", 
              "author": "John Doe"
              }
    
    
)
doc
# Out:
# Document(metadata={'source': 'sample_source', 'author': 'John Doe'}, page_content='This is a sample document.')

# %%
## create a simple txt file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/sample1.txt":"""Python programming Introduction
    Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming. It has a large standard library and a vibrant community that contributes to a wide range of third-party packages and frameworks.
    Python is widely used in various domains, such as web development, data analysis, artificial intelligence, scientific computing, and automation. Its versatility and ease of use make it a popular choice for both beginners and experienced developers.""",
    }

for filepath, content in sample_texts.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)
        
print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %%
## text loader
from langchain_community.document_loaders import TextLoader 

loader = TextLoader("../data/text_files/sample1.txt",encoding="utf-8")
loader
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_21024\1529595033.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/sample1.txt'}, page_content='Python programming Introduction\n    Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming. It has a large standard library and a vibrant community that contributes to a wide range of third-party packages and frameworks.\n    Python is widely used in various domains, such as web development, data analysis, artificial intelligence, scientific computing, and automation. Its versatility and ease of use make it a popular choice for both beginners and experienced developers.')]

# %%
## TextLoader
from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader("../data/text_files/sample1.txt", encoding="utf-8")
loader

# %%
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/sample1.txt'}, page_content='Python programming Introduction\n    Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming. It has a large standard library and a vibrant community that contributes to a wide range of third-party packages and frameworks.\n    Python is widely used in various domains, such as web development, data analysis, artificial intelligence, scientific computing, and automation. Its versatility and ease of use make it a popular choice for both beginners and experienced developers.')]

# %%
## we can also load multiple files using glob pattern

# %%
## same can be done for pdfs using PyPDFLoader

# %%
## langchain document loaders are designed to handle various document formats, including text files, PDFs, and more. They provide a convenient way to load and process documents for further analysis or processing in your applications.
